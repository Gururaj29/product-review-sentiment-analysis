# %% [markdown]
# # Mounts, installations and imports

# %%
# Mount workspace
from google.colab import drive
drive.mount('/content/drive')
# !unzip -o -u "/content/drive/My Drive/ASU/Spring24/DataMining/DM-Project/product-review-sentiment-analysis.zip" -d "."
# Out:
# Mounted at /content/drive
# Archive:  /content/drive/My Drive/ASU/Spring24/DataMining/DM-Project/product-review-sentiment-analysis.zip
#    creating: ./visualization/
#   inflating: ./visualization/visualization.py
#    creating: ./preprocessors/
#   inflating: ./preprocessors/loaders.py
#   inflating: ./preprocessors/features.py
#  extracting: ./Makefile
#    creating: ./utils/
#   inflating: ./utils/constants.py
#   inflating: ./utils/utils.py
#    creating: ./models/
#    creating: ./models/LLM/
#   inflating: ./models/LLM/gpt2.py
#   inflating: ./models/LLM/DistilBert.py
#   inflating: ./models/LLM/BART.py
#   inflating: ./models/LLM/llama.py
#   inflating: ./models/NN.py
#    creating: ./models/RNN/
#   inflating: ./models/RNN/cnn.py
#   inflating: ./models/RNN/lstm.py
#    creating: ./evaluators/
#   inflating: ./evaluators/evaluators.py
#   inflating: ./preprocessing.py
#    creating: ./Data/
#    creating: ./Data/raw_data/
#    creating: ./Data/raw_data/Amazon/
#   inflating: ./Data/raw_data/Amazon/test.csv
#   inflating: ./Data/raw_data/Amazon/train.csv
#    creating: ./Data/raw_data/Yelp/
#   inflating: ./Data/raw_data/Yelp/test.csv
#   inflating: ./Data/raw_data/Yelp/train.csv
#    creating: ./Data/small_features/
#    creating: ./Data/small_features/Amazon/
#    creating: ./Data/small_features/Amazon/GloVe/
#   inflating: ./Data/small_features/Amazon/GloVe/test.csv
#   inflating: ./Data/small_features/Amazon/GloVe/train.csv
#    creating: ./Data/small_features/Amazon/CountVectorizer/
#   inflating: ./Data/small_features/Amazon/CountVectorizer/test.csv
#   inflating: ./Data/small_features/Amazon/CountVectorizer/train.csv
#    creating: ./Data/small_features/Amazon/TFIDF/
#   inflating: ./Data/small_features/Amazon/TFIDF/test.csv
#   inflating: ./Data/small_features/Amazon/TFIDF/train.csv
#    creating: ./Data/small_features/Yelp/
#    creating: ./Data/small_features/Yelp/GloVe/
#   inflating: ./Data/small_features/Yelp/GloVe/test.csv
#   inflating: ./Data/small_features/Yelp/GloVe/train.csv
#    creating: ./Data/small_features/Yelp/CountVectorizer/
#   inflating: ./Data/small_features/Yelp/CountVectorizer/test.csv
#   inflating: ./Data/small_features/Yelp/CountVectorizer/train.csv
#    creating: ./Data/small_features/Yelp/TFIDF/
#   inflating: ./Data/small_features/Yelp/TFIDF/test.csv
#   inflating: ./Data/small_features/Yelp/TFIDF/train.csv
#  extracting: ./analysis.ipynb

# %%
# installations
# !pip install stormtrooper
# Out:
# Requirement already satisfied: stormtrooper in /usr/local/lib/python3.10/dist-packages (0.4.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from stormtrooper) (3.9.3)
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from stormtrooper) (1.25.2)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from stormtrooper) (1.2.2)
# Requirement already satisfied: thefuzz<0.19.0,>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from stormtrooper) (0.18.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.60.0 in /usr/local/lib/python3.10/dist-packages (from stormtrooper) (4.66.2)
# Requirement already satisfied: transformers<5.0.0,>=4.25.0 in /usr/local/lib/python3.10/dist-packages (from stormtrooper) (4.38.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.0->stormtrooper) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.0->stormtrooper) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.0->stormtrooper) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.0->stormtrooper) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.0->stormtrooper) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.0->stormtrooper) (4.0.3)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=1.2.0->stormtrooper) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=1.2.0->stormtrooper) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=1.2.0->stormtrooper) (3.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.25.0->stormtrooper) (3.13.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.25.0->stormtrooper) (0.20.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.25.0->stormtrooper) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.25.0->stormtrooper) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.25.0->stormtrooper) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.25.0->stormtrooper) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.25.0->stormtrooper) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.25.0->stormtrooper) (0.4.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers<5.0.0,>=4.25.0->stormtrooper) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers<5.0.0,>=4.25.0->stormtrooper) (4.10.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.0->aiohttp<4.0.0,>=3.8.0->stormtrooper) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5.0.0,>=4.25.0->stormtrooper) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5.0.0,>=4.25.0->stormtrooper) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5.0.0,>=4.25.0->stormtrooper) (2024.2.2)

# %%
# Imports
# external imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# internal imports
from preprocessors import loaders
from utils import constants
from utils import utils
from visualization import visualization
from evaluators import evaluators
from models.LLM import DistilBert

# %% [markdown]
# # Amazon Dataset

# %% [markdown]
# ## Load dataset

# %%
amazon_train_df, amazon_test_df = loaders.load_raw_data(constants.DatasetAmazon)
visualization.plot_label_distribution(amazon_train_df, amazon_test_df)

# %% [markdown]
# ## Model Initialization

# %%
model = DistilBert.ZeroShotClassifier(model="google-bert/bert-base-uncased",device=0)
model_name = "DistilBert_ZeroShotClassifier"
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at google-bert/bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Failed to determine 'entailment' label id from the label2id mapping in the model config. Setting to -1. Define a descriptive label2id mapping in the model config to ensure correct outputs.

# %% [markdown]
# ## Model Evaluation

# %%
amazonEvalResults = evaluators.evaluate(model, amazon_train_df, amazon_test_df, "Amazon")
print("Training and testing accuracies for amazon dataset are %f and %f respectively" %amazonEvalResults.get_accuracies())
# Out:
# Time taken (in seconds) for training:  7.977999999297936e-06
#   1%|          | 6/1001 [00:02<04:55,  3.37it/s]/usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# 100%|██████████| 1001/1001 [00:27<00:00, 36.70it/s]
# Time taken (in seconds) for predicting Train dataset: 26.041707
#   0%|          | 0/1001 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# 100%|██████████| 1001/1001 [00:25<00:00, 38.98it/s]
# Time taken (in seconds) for predicting Test dataset: 25.212450
# Training and testing accuracies for amazon dataset are 0.663337 and 0.712288 respectively

# %%
amazonEvalResults.plot_confusion_matrices()

# %%
# Test data classification report
amazonEvalResults.display_classification_report(False)
# Out:
# ╒══════════════╤═════════════╤══════════╤════════════╤═══════════╕
# │              │   precision │   recall │   f1-score │   support │
# ╞══════════════╪═════════════╪══════════╪════════════╪═══════════╡
# │ Negative     │    0.641264 │ 0.784091 │   0.705521 │       440 │
# ├──────────────┼─────────────┼──────────┼────────────┼───────────┤
# │ Positive     │    0.794816 │ 0.655971 │   0.71875  │       561 │
# ├──────────────┼─────────────┼──────────┼────────────┼───────────┤
# │ macro avg    │    0.71804  │ 0.720031 │   0.712136 │      1001 │
# ├──────────────┼─────────────┼──────────┼────────────┼───────────┤
# │ weighted avg │    0.727321 │ 0.712288 │   0.712935 │      1001 │
# ╘══════════════╧═════════════╧══════════╧════════════╧═══════════╛

# %% [markdown]
# # Yelp Dataset

# %% [markdown]
# ## Load Dataset

# %%
yelp_train_df, yelp_test_df = loaders.load_raw_data(constants.DatasetYelp)
visualization.plot_label_distribution(yelp_train_df, yelp_test_df)

# %% [markdown]
# ## Model Evaluation

# %%
yelpEvalResults = evaluators.evaluate(model, yelp_train_df, yelp_test_df, "Yelp")
print("Training and testing accuracies for yelp dataset are %f and %f respectively" %yelpEvalResults.get_accuracies())
# Out:
# Time taken (in seconds) for training:  1.3777999996023027e-05
#   0%|          | 0/1000 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#   1%|          | 12/1000 [00:00<00:22, 43.08it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-b45a942b3389> in <cell line: 1>()
# ----> 1 yelpEvalResults = evaluators.evaluate(model, yelp_train_df, yelp_test_df, "Yelp")
#       2 print("Training and testing accuracies for yelp dataset are %f and %f respectively" %yelpEvalResults.get_accuracies())
#
# /content/evaluators/evaluators.py in evaluate(model, train_df, test_df, evaluator_name, print_time)
#      70     if print_time:
#      71         print("Time taken (in seconds) for training: ", train_time)
# ---> 72     return EvaluatorResults(model, evaluator_name = evaluator_name, train_df=train_df, test_df=test_df, train_time=train_time, print_time=print_time)
#      73
#      74 class EvaluatorResults:
#
# /content/evaluators/evaluators.py in __init__(self, model, evaluator_name, train_df, test_df, train_time, print_time, train_output_filepath, test_output_filepath)
#     109         if train_df is not None:
#     110            self.train_true_labels = train_df[constants.ColumnLabel]
# --> 111            self.train_pred_labels, self.train_pred_time, self.train_classification_report, self.train_confusion_matrix = self.__pred(
#     112               model, train_df, self.train_true_labels, print_time, "Train")
#     113            self.train_accuracy = self.train_classification_report['accuracy']
#
# /content/evaluators/evaluators.py in __pred(self, model, df, true_labels, print_time, dataset)
#      75     def __pred(self, model, df, true_labels, print_time, dataset):
#      76         start_time = time.process_time()
# ---> 77         pred_labels = model.predict(df.drop([constants.ColumnLabel], axis=1))
#      78         pred_time = time.process_time() - start_time
#      79
#
# /content/models/LLM/gpt2.py in predict(self, data_df)
#      16
#      17     for review in tqdm(data_df[constants.ColumnData]):
# ---> 18       prediction = self.classifier(review, candidate_labels=labels)
#      19       label, scores = prediction["labels"], prediction["scores"]
#      20       predicted_class = label[0] if scores[0] >= scores[1] else label[0]
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/zero_shot_classification.py in __call__(self, sequences, *args, **kwargs)
#     204             raise ValueError(f"Unable to understand extra arguments {args}")
#     205
# --> 206         return super().__call__(sequences, **kwargs)
#     207
#     208     def preprocess(self, inputs, candidate_labels=None, hypothesis_template="This example is {}."):
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1186             return self.iterate(inputs, preprocess_params, forward_params, postprocess_params)
#    1187         elif self.framework == "pt" and isinstance(self, ChunkPipeline):
# -> 1188             return next(
#    1189                 iter(
#    1190                     self.get_iterator(
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/pt_utils.py in __next__(self)
#     122
#     123         # We're out of items within a batch
# --> 124         item = next(self.iterator)
#     125         processed = self.infer(item, **self.params)
#     126         # We now have a batch of "inferred things".
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/pt_utils.py in __next__(self)
#     264
#     265         while not is_last:
# --> 266             processed = self.infer(next(self.iterator), **self.params)
#     267             if self.loader_batch_size is not None:
#     268                 if isinstance(processed, torch.Tensor):
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in forward(self, model_inputs, **forward_params)
#    1100                 with inference_context():
#    1101                     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1102                     model_outputs = self._forward(model_inputs, **forward_params)
#    1103                     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1104             else:
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/zero_shot_classification.py in _forward(self, inputs)
#     227         if "use_cache" in inspect.signature(model_forward).parameters.keys():
#     228             model_inputs["use_cache"] = False
# --> 229         outputs = self.model(**model_inputs)
#     230
#     231         model_outputs = {
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, input_ids, attention_mask, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1000         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1001
# -> 1002         distilbert_output = self.distilbert(
#    1003             input_ids=input_ids,
#    1004             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     812         head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     813
# --> 814         embeddings = self.embeddings(input_ids, inputs_embeds)  # (bs, seq_length, dim)
#     815
#     816         if self._use_flash_attention_2:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, input_ids, input_embeds)
#     154         position_embeddings = self.position_embeddings(position_ids)  # (bs, max_seq_length, dim)
#     155
# --> 156         embeddings = input_embeds + position_embeddings  # (bs, max_seq_length, dim)
#     157         embeddings = self.LayerNorm(embeddings)  # (bs, max_seq_length, dim)
#     158         embeddings = self.dropout(embeddings)  # (bs, max_seq_length, dim)
#
# RuntimeError: The size of tensor a (1025) must match the size of tensor b (512) at non-singleton dimension 1

# %%
yelpEvalResults.plot_confusion_matrices()

# %% [markdown]
# # Comparing performances of the model

# %%
visualization.plot_accuracies_from_results([amazonEvalResults, yelpEvalResults], "Ecommerce platform")

# %%
visualization.plot_pred_time_from_results([amazonEvalResults, yelpEvalResults], "Ecommerce platform")
